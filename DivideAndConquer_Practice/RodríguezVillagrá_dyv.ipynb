# %% [markdown]
# # Algoritmia
#
# ## Práctica 2 - Divide y Vencerás
#
# ### Curso 2023 - 2024
#
# ---
#
# #### Autores:
#
# - César Rodríguez Villagrá
#
# ---
#
# Resuelva la siguiente práctica.
#
# Importe las librerías que desees
# **Recuerda**:
#
# - Solamente puedes utilizar bibliotecas nativas (https://docs.python.org/es/3.8/library/index.html)
# - Las funciones que importes no son "gratis", cada una tendrá una complejidad temporal y espacial que se tendrá que tener en cuenta.

# %%
#testeable
# imports

# %%
#testeable
# Versión ligeramente modificada de la clase Video de la Práctica 1

# Se ha incluido una propiedad 'fee', correspondiente a los costes
# semanales de licenciamiento del contenido
class Video:
    """
    Clase Video. 
    Representa una serie o película.
    """

    def __init__(self, name, size, fee):
        """Crea un objeto de clase Video

        Parameters
        ----------
        name : str
            Nombre de la serie/película
        size : number
            Tamaño en memoria de la serie/película
        """
        self.name = name
        self.size = size
        self.fee = fee
        self.espectadores: dict = {}

    def __hash__(self):
        """Genera el valor hash identificativo del vídeo

        Returns
        -------
        int
            Valor hash
        """
        return hash((self.name, self.size, self.fee))

    def __str__(self):
        """Genera una cadena descriptiva del objeto

        Returns
        -------
        str
            Cadena descriptiva
        """
        return f"{self.name}"

    def __repr__(self):
        """Genera una cadena descriptiva del objeto dentro de colecciones

        Returns
        -------
        str
            Cadena descriptiva
        """
        return str(self)

    def set_users(self, country, users):
        """Dado un pais y un número de usuarios
           almacena para este vídeo la cantidad de espectadores que tiene.

        Parameters
        ----------
        country : str
            País desde donde se ve la serie/película
        users : int
            Número de espectadores
        """
        self.espectadores[country] = users

    def get_users(self, country):
        """Dado un país, obtiene el número de usuarios.

        Parameters
        ----------
        country : str
            País desde donde se ve la serie/película

        Returns
        -------
        int
            Número de espectadores para el país `country`
        """
        self.espectadores.get(country, 0)

    def __ge__(self, other):
        """Muestra si un objeto es mayor o igual que otro

        Parameters
        ----------
        other : Video
            Video a comparar

        Returns
        -------
        Boolean
            True si es mayor o igual que otro, False en caso contrario
        """
        if isinstance(other, Video):
            return self.size >= other.size
        return False

    def __lt__(self, other):
        """Muestra si un objeto es menor que otro

        Parameters
        ----------
        other : Video
            Video a comparar

        Returns
        -------
        Boolean
            True si es menor que otro, False en caso contrario
        """
        if isinstance(other, Video):
            return self.size < other.size
        return False

# %%
#testeable

def key_sort(seq, key_function=lambda x: x, reverse=False):
    """Ordena ascendentemente una secuencia utilizando una función clave.

    Parameters
    ----------
    seq : sequence
        Secuencia a ordenar, por ejemplo una lista
    key_function : int
        Función que devuelve para los elementos de la secuencia un valor
        clave para la ordenación
    reverse: boolean
        Si es True Invierte el orden de la ordenación.

    Notes
    -----
    No tiene retorno. Ordena en el sitio la secuencia de entrada.
    """
    def mergeSort(lista: list, prim: int, ult: int) -> None:
        """Implementación del método de ordenación mergeSort en el sitio.

        Parameters
        ----------
        lista : list
            Lista a ordenar
        prim : int
            Índice del primer elemento a ordenar
        ult : int
            Índice del último elemento a ordenar
        """
        if prim < ult:
            medio: int = (prim+ult)//2
            mergeSort(lista, prim, medio)
            mergeSort(lista, medio + 1, ult)
            i: int = prim
            j: int = medio + 1
            temp: list = []
            while i <= medio and j <= ult:
                if key_function(lista[i]) <= key_function(lista[j]):
                    temp.append(lista[i])
                    i += 1
                else:
                    temp.append(lista[j])
                    j += 1
            while i <= medio:
                temp.append(lista[i])
                i += 1
            while j <= ult:
                temp.append(lista[j])
                j += 1
            for pos in range(prim, ult+1):
                lista[pos] = temp[pos - prim]
    mergeSort(seq, 0, len(seq) - 1)
    if reverse == True:
        seq.reverse()

# %%
#testeable

def max_emission_profit(video, forecast, ingresos_por_usuario, method="bruteforce"):
    """Calcula el máximo beneficio obtenible emitiendo un vídeo según 
       la previsión de espectadores disponible.

    Parameters
    ----------
    video : Video
        Vídeo a emitir.
    forecast : iterable
        Previsión de espectadores.
    ingresos_por_usuario: float
        Ingresos brutos que proporciona cada usuario.
    method: String
        Algoritmo a emplear 'bruteforce' o 'divideandconquer'.

    Returns
    -------
    float
        Máximo beneficio obtenible.

    Notes
    -----
    El máximo beneficio se calcula considerando la mejor combinación 
    posible de momento de inicio y finalización dentro del periodo de 
    forecast, el coste de licenciamiento del vídeo (fee) y los beneficios 
    obtenidos por cada espectador. Si el vídeo no puede emitirse de forma
    rentable, el método devuelve 0.
    'video' debe disponer de una propiedad 'fee' que establece los costes
    de licenciamiento en periodos equivalentes a las previsiones de 'forecast'.
    """
    def calcularBeneficio(elemento:int) -> float:
        """Calcula el beneficio del índice del elemento pasado.

        Parameters
        ----------
        elemento : int
            Índice de la previsión de espectadores.

        Returns
        -------
        float
            El beneficio correspondiente.
        """
        return forecast[elemento] * ingresos_por_usuario - video.fee

    if method == 'bruteforce':
        maximo: float = 0.0
        for inicio in range(len(forecast)):
            calculo: float = 0.0
            for fin in range(inicio, len(forecast)):
                calculo += calcularBeneficio(fin)
                if calculo > maximo:
                    maximo: float = calculo
        return maximo
    elif method == 'divideandconquer':
        def divYVen(indiceIzq: int, indiceDer: int) -> tuple[float, int, int]:
            """Algoritmo divide y vencerás para calcular el máximo beneficio en un rango de semanas a partir de la previsión de cada semana

            Parameters
            ----------
            indiceIzq : int
                Índice inicial
            indiceDer : int
                Índice final

            Returns
            -------
            tuple[float, int, int]
                Una tupla que contiene el mayor beneficio, junto con los índices de inicio y de fin que generan ese beneficio
            """
            def calcularBeneficioCentro(izq: int, der: int) -> tuple[float, int, int]:
                """Calcula el máximo beneficio la lista de previsiones entre los índices pasados que pase por el centro de ambos. 

                Parameters
                ----------
                izq : int
                    Índice izquierdo
                der : int
                    Índice derecho

                Returns
                -------
                tuple[float, int, int]
                    Una tupla que contiene el mayor beneficio que pasa por el centro, junto con los índices de inicio y de fin que generan ese beneficio
                """
                medio: int = (izq+der)//2
                nuevoIzq = nuevoDer = medio

                maxSumIzq = maxSumDer = -float('inf')
                sumaIzq = sumaDer = 0.0

                for i in range(medio, izq-1, -1):
                    sumaIzq += calcularBeneficio(i)
                    if sumaIzq > maxSumIzq:
                        maxSumIzq: float = sumaIzq
                        nuevoIzq: int = i
                for i in range(medio+1, der+1):
                    sumaDer += calcularBeneficio(i)
                    if sumaDer > maxSumDer:
                        maxSumDer: float = sumaDer
                        nuevoDer: int = i

                return maxSumIzq + maxSumDer, nuevoIzq, nuevoDer

            if indiceIzq == indiceDer:
                return calcularBeneficio(indiceIzq), indiceIzq, indiceDer
            medio: int = (indiceIzq+indiceDer)//2
            benIzq, indiceIzq1, indiceDer1 = divYVen(indiceIzq, medio)
            benDer, indiceIzq2, indiceDer2 = divYVen(medio+1, indiceDer)

            if indiceDer2-indiceIzq1 > 1:
                beneficioCentro: tuple[float, int, int] = calcularBeneficioCentro(
                    indiceIzq1, indiceDer2)
            else:
                beneficioCentro = (benIzq + benDer, indiceIzq1, indiceDer2)

            if (beneficioCentro[0] >= benIzq and beneficioCentro[0] >= benDer):
                return beneficioCentro
            else:
                if benIzq > benDer:
                    return benIzq, indiceIzq1, indiceDer1
                else:
                    return benDer, indiceIzq2, indiceDer2

        if len(forecast) == 0:
            return 0.0
        beneficio: float = divYVen(0, len(forecast)-1)[0]
        if beneficio < 0:
            return 0.0

        return beneficio
    else:
        pass

# %%
#testeable
def optimize_content_grid(videos, forecasts, ingresos_por_usuario, k=None):
    """Obtiene los vídeos rentables para su emisión según la previsión
    de espectadores y los ingresos por usuario.

    Parameters
    ----------
    videos : list of Video
        Vídeos a analizar.
    forecasts : list of list of int
        Secuencia de previsiones para los vídeos
    ingresos_por_usuario: float
        Ingresos brutos que proporciona cada usuario.
    k: int
        Obtiene los k elementos más rentables.

    Returns
    -------
    list
        Lista con los k elementos más rentables.

    Notes
    -----
    La rentabilidad de los vídeos se considera tomando el periodo
    óptimo de emisión para cada uno. El método sólo devuelve resultados
    con rentabilidad mayor que 0.
    """

    videosRent: list[Video] = []
    for i, video in enumerate(videos):
        beneficio: float = max_emission_profit(
            video, forecasts[i], ingresos_por_usuario, method='divideandconquer')
        if beneficio > 0:
            videosRent.append((video, beneficio))
    key_sort(videosRent, key_function=lambda x: x[1], reverse=True)

    for i, vid in enumerate(videosRent):
        videosRent[i] = vid[0]

    if k == None:
        return videosRent
    if k >= 0 and k < len(videosRent):
        return videosRent[:k]
    else:
        return videosRent

# %% [markdown]
# ### Caso de ejemplo

# %%
import unittest
import random

# Vídeos de ejemplo para tests
videos_test = [Video("Vikings: Valhalla", 150, 1500),  # Título, tamaño, fee
               Video("New Amsterdam", 56, 980),
               Video("Juego de Tronos", 152, 2500),
               Video("La casa de papel", 76, 800),
               Video("Breaking Bad", 160, 1230),
               Video("Pasión de gavilanes", 125, 350),
               Video("The Sinner", 89, 1900),
               Video("El Cid", 35, 410),
               Video("Raised by wolves", 80, 1900),
               Video("Euphoria", 90, 2000),
               Video("Peacemaker", 40, 1000)]

# Audiencias previstas para los anteriores
forecasts_test = [[500, 1000, 2000,  150, 2000, 1500,  200, 1200,  700],
                  [1000,  800,  500,  250, 4000,  500,  100,  200,  300],
                  [1200, 1000,  900,  900, 1220, 1100,  900, 1000, 1000],
                  [900,  700,  500,  200, 1600,  200,  300,  250,  100],
                  [600,  900, 1240,  250, 2100, 1000,  350, 1000,  800],
                  [190, 1060,  500,  200,  250,  700,  200,  400,  400],
                  [150, 1100, 2500,  600,  800, 3000,  200, 1000,  900],
                  [160,  100,  200,  200,  150,  200,   50,  200,  190],
                  [900,  850,  960,  950, 1100,  100,  350,  900,  800],
                  [600,  900, 1200,  300, 1900, 1000,  650,  850,  800],
                  [510,  500,  500,  500,  500,  500,  500,  500,  510]]


class TestBasico(unittest.TestCase):

    def test_basic_sort(self):
        v = list(range(100))
        random.seed = 1234
        random.shuffle(v)
        key_sort(v)
        self.assertEqual(v, list(range(100)))

    def test_max_profit(self):
        for m in ["bruteforce", "divideandconquer"]:
            self.assertEqual(max_emission_profit(
                Video("test", 99, 1), [1]*10, 1, method=m), 0)
            self.assertEqual(max_emission_profit(
                Video("test", 99, 1), [1]*10, 1, method=m), 0)
            self.assertEqual(max_emission_profit(
                Video("test", 99, 1), [2]*10, 1, method=m), 10)


if __name__ == "__main__":
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.002s
#
# OK

# %% [markdown]
# ##### **Tests**
#
# Para probar que tu solución pasa los tests. Utilice el comando:
#
# ```bash
# $ python tests-py3<version de python> <mi notebook>
# ```
#
# Los tests necesitan de la librería `nbformat`
#
# ```bash
# $ pip install nbformat
# ```
#
# ###### Explicación de los tests
#
# - `test_ej1_basic_sort`: Comprueba que se ordenen correctamente listas de números.
# - `test_ej1_key_sort`: Comprueba que se ordenan correctamente listas según su función clave.
# - `test_ej1_video_sort`: Comprueba que se pueden ordenar vídeos.
# - `test_ej2_max_profit`: Comprueba que se obtiene el beneficio máximo tanto por fuerza bruta como por divide y vencerás para listas de números simples.
# - `test_ej2_max_profit_dataset`: Comprueba que se obtiene el beneficio máximo tanto por fuerza bruta como por divide y vencerás para listas más complejas.
# - `test_ej2_optimize_content_grid`: Comprueba el buen desempeño de la función `optimize_content_grid`.
#
# ---

# %% [markdown]
# ### **Informe**
#
# Contesta a las siguientes preguntas.

# %% [markdown]
# #### **Complejidad**
#
# 1. Método `key_sort`
#    - **Complejidad temporal**: Según el teorema maestro, tiene una complejidad de n*Log(n), si la función key_function es O(1) , donde n, es el número de elementos a ordenar, pero si la complejidad de key_function es mayor que O(1), la complejidad de key_sort sería O(n\*O(key_function)).
#   Por ejemplo si la complejidad de key_function es O(n), la complejidad de key_sort sería O(n^2), en regla general, si la complejidad de key_function es mayor que O(1), la complejidad sería O(n\*i), donde i es la complejidad de la key_function.
# 2. Método `max_emission_profit`
#    - **Complejidad temporal**: La complejidad de la función es O(n^2), cuando el método es bruteforce,  y O(n\*log(n)), cuando el método es divideandconquer.
# 3. Método `optimize_content_grid`
#    - **Complejidad temporal**: La complejidad de la función es O(n^2\*log(n)), ya que usamos, para cada vídeo de entrada la función max_emission_profit con el método divideandconquer (O(n\*log(n))), por lo que la complejidad es O(n\*n\*log(n))

# %% [markdown]
# #### **Ranking de contenidos.**
#
# - ¿Cómo afecta la función clave, que proporciona el criterio de ordenación, a la complejidad temporal del algoritmo?
#
# Tiene una complejidad de n\*Log(n), si la función key_function es O(1) , donde n, es el número de elementos a ordenar, pero si la complejidad de key_function es mayor que O(1), la complejidad de key_sort sería O(n\*O(key_function)).
# Esto se debe, a que, aplicando el teorema Maestro, donde la estructura es T(n) = aT(n/b) + O(n^k), en el que en este caso sería de la forma T(n) = 2T(n/2) + n, contando que la key_function es O(1), porque, siendo a=2, b=2, y k=1, como a=b^k, la complejidad es O(n\*log(n)), en el caso que key_function es mayor que O(1), a=2, b=2, y k=i+1, donde i es el grado de la complejidad de key_function, por lo que a < b^k: 2 < 2^(1+i), siendo i > 0, por lo que la complejidad se queda en O(n^k), donde k es mayor que 1.
#
# Por ejemplo si la complejidad de key_function es O(n), la complejidad de key_sort sería O(n^2), en regla general, si la complejidad de key_function es mayor que O(1), la complejidad sería O(n\*i), donde i es la complejidad de la key_function.
#
# #### **Optimización de la compra de contenidos.**
#
# - ¿Has conseguido mejorar la complejidad temporal mediante la solución Divide y Vencerás?
# - ¿Por qué ha mejorado? ¿Cuánto ha mejorado? <br>
#   <sub>Pon algunos ejemplos numéricos especulativos que relacionen el tamaño del problema con el tiempo de ejecución en ambas versiones. Contrástalos de forma empírica empleando para ello tu implementación.</sub>
#
# Sí, se ha reducido la complejidad de O(n^2), a O(n\*Log(n)), por lo que, cuanto más elementos haya, más diferencia de tiempos habrá, obteniendo ambas el mismo resultado.
# En listas muy pequeñas, tendrán tiempos parecidos, pero cada vez serán menos parecidos.
#
# Siguendo las fórmulas de la complejidad, por ejemplo, en una lista de 2 elementos, puede tardar alrededor de 4 unidades el bruteforce, y 2 el de divide y vencerás, siguiendo la fórmula de cada complejidad, con 10 elementos, podría tardar, 100 unidades de tiempo el bruteforce, y alrededor de 33 el divideandconquer, con 100 elementos tardaría alrededor de 10000 unidades y 665 el divideandconquer. Como se ve se puede apreciar que cuanto más grande es la lista, myor es la diferencia en los tiempos, para comprobarlo, he hecho una celda que medirán los tiempos, de ejecución, para el mismo problema, los 2 algoritmos, con cantidades entre 1 y 10000, en el que se van a generar datos aleatorios, para cada iteración, también cada iteración se repite 20 veces para reducir las posibles irregularidades, y muestra la media de esas 20 iteraciones, porque puede haber momentos puntuales en el que el SO le proporcione menos recursos al intérprete de python, y por consecuencia tarde "más de lo debido".
#
# En la salida de la siguiente celda se puede apreciar que la diferencia de tiempos, va del orden de 10^-7, hasta los 3 segundos con 5000 elementos, o incluso 9 segundos con 9000 elementos.

# %%
import random
import time

repeticiones: int = 20
tamanos: list[int] = [
    *range(1, 50), *range(50, 1000, 10), *range(1000, 10000, 1000)]
for i in tamanos:
    tiempost1: list[int] = []
    tiempost2: list[int] = []
    for _ in range(repeticiones):
        size:  int = random.randint(1, 200)
        fee: int = random.randint(0, 500)
        vid = Video(f"Prueba{i}-{size}-{fee}", size, fee)
        lista: list[int] = list(range(i))
        random.shuffle(lista)
        ing: int = random.randrange(0, 50)
        tIni1: float = time.perf_counter()
        max_emission_profit(vid, lista, ing, method="bruteforce")
        tFin1: float = time.perf_counter()
        tIni2: float = time.perf_counter()
        max_emission_profit(vid, lista, ing, method="divideandconquer")
        tFin2: float = time.perf_counter()
        t1: float = tFin1-tIni1
        t2: float = tFin2-tIni2
        tiempost1.append(t1)
        tiempost2.append(t2)
    t1 = sum(tiempost1) / len(tiempost1)
    t2 = sum(tiempost2) / len(tiempost2)

    print(f"Tamaño: {i:5d} - Fuerza Bruta: {t1:.2e}s, Divide y Vencerás: {t2:.2e}s, Mejora: {(t1-t2)/t1*100:+9.4f} %, Diferencia de tiempos: {t1-t2:+.3e}")
# Out:
# Tamaño:     1 - Fuerza Bruta: 1.41e-05s, Divide y Vencerás: 3.43e-06s, Mejora:  +75.6824 %, Diferencia de tiempos: +1.067e-05
# Tamaño:     2 - Fuerza Bruta: 3.00e-06s, Divide y Vencerás: 4.89e-06s, Mejora:  -63.2722 %, Diferencia de tiempos: -1.895e-06
# Tamaño:     3 - Fuerza Bruta: 4.10e-06s, Divide y Vencerás: 7.64e-06s, Mejora:  -86.5684 %, Diferencia de tiempos: -3.545e-06
# Tamaño:     4 - Fuerza Bruta: 1.00e-05s, Divide y Vencerás: 9.28e-06s, Mejora:   +7.2463 %, Diferencia de tiempos: +7.250e-07
# Tamaño:     5 - Fuerza Bruta: 6.55e-06s, Divide y Vencerás: 1.21e-05s, Mejora:  -84.0582 %, Diferencia de tiempos: -5.510e-06
# Tamaño:     6 - Fuerza Bruta: 8.12e-06s, Divide y Vencerás: 1.45e-05s, Mejora:  -78.8924 %, Diferencia de tiempos: -6.410e-06
# Tamaño:     7 - Fuerza Bruta: 1.02e-05s, Divide y Vencerás: 2.48e-05s, Mejora: -142.8991 %, Diferencia de tiempos: -1.459e-05
# Tamaño:     8 - Fuerza Bruta: 1.28e-05s, Divide y Vencerás: 1.94e-05s, Mejora:  -52.1944 %, Diferencia de tiempos: -6.660e-06
# Tamaño:     9 - Fuerza Bruta: 1.56e-05s, Divide y Vencerás: 2.39e-05s, Mejora:  -53.5497 %, Diferencia de tiempos: -8.335e-06
# Tamaño:    10 - Fuerza Bruta: 1.73e-05s, Divide y Vencerás: 3.22e-05s, Mejora:  -86.0283 %, Diferencia de tiempos: -1.487e-05
# Tamaño:    11 - Fuerza Bruta: 2.03e-05s, Divide y Vencerás: 2.91e-05s, Mejora:  -43.3916 %, Diferencia de tiempos: -8.815e-06
# Tamaño:    12 - Fuerza Bruta: 2.32e-05s, Divide y Vencerás: 3.13e-05s, Mejora:  -35.2547 %, Diferencia de tiempos: -8.165e-06
# Tamaño:    13 - Fuerza Bruta: 2.67e-05s, Divide y Vencerás: 3.39e-05s, Mejora:  -26.9361 %, Diferencia de tiempos: -7.200e-06
# Tamaño:    14 - Fuerza Bruta: 3.04e-05s, Divide y Vencerás: 4.46e-05s, Mejora:  -46.5472 %, Diferencia de tiempos: -1.415e-05
# Tamaño:    15 - Fuerza Bruta: 3.32e-05s, Divide y Vencerás: 3.88e-05s, Mejora:  -16.7720 %, Diferencia de tiempos: -5.575e-06
# Tamaño:    16 - Fuerza Bruta: 4.08e-05s, Divide y Vencerás: 4.33e-05s, Mejora:   -6.1337 %, Diferencia de tiempos: -2.505e-06
# Tamaño:    17 - Fuerza Bruta: 4.11e-05s, Divide y Vencerás: 5.44e-05s, Mejora:  -32.4239 %, Diferencia de tiempos: -1.331e-05
# Tamaño:    18 - Fuerza Bruta: 4.41e-05s, Divide y Vencerás: 4.97e-05s, Mejora:  -12.6972 %, Diferencia de tiempos: -5.595e-06
# Tamaño:    19 - Fuerza Bruta: 4.93e-05s, Divide y Vencerás: 5.38e-05s, Mejora:   -9.0697 %, Diferencia de tiempos: -4.475e-06
# Tamaño:    20 - Fuerza Bruta: 5.42e-05s, Divide y Vencerás: 5.83e-05s, Mejora:   -7.5801 %, Diferencia de tiempos: -4.105e-06
# Tamaño:    21 - Fuerza Bruta: 5.80e-05s, Divide y Vencerás: 8.25e-05s, Mejora:  -42.2596 %, Diferencia de tiempos: -2.450e-05
# Tamaño:    22 - Fuerza Bruta: 6.41e-05s, Divide y Vencerás: 6.67e-05s, Mejora:   -4.0958 %, Diferencia de tiempos: -2.625e-06
# Tamaño:    23 - Fuerza Bruta: 6.87e-05s, Divide y Vencerás: 6.50e-05s, Mejora:   +5.5200 %, Diferencia de tiempos: +3.795e-06
# Tamaño:    24 - Fuerza Bruta: 8.77e-05s, Divide y Vencerás: 8.52e-05s, Mejora:   +2.9180 %, Diferencia de tiempos: +2.560e-06
# Tamaño:    25 - Fuerza Bruta: 9.37e-05s, Divide y Vencerás: 8.48e-05s, Mejora:   +9.5093 %, Diferencia de tiempos: +8.915e-06
# Tamaño:    26 - Fuerza Bruta: 9.00e-05s, Divide y Vencerás: 8.17e-05s, Mejora:   +9.2474 %, Diferencia de tiempos: +8.325e-06
# Tamaño:    27 - Fuerza Bruta: 9.67e-05s, Divide y Vencerás: 8.18e-05s, Mejora:  +15.4526 %, Diferencia de tiempos: +1.495e-05
# Tamaño:    28 - Fuerza Bruta: 1.15e-04s, Divide y Vencerás: 9.80e-05s, Mejora:  +14.5540 %, Diferencia de tiempos: +1.670e-05
# Tamaño:    29 - Fuerza Bruta: 1.07e-04s, Divide y Vencerás: 8.60e-05s, Mejora:  +19.5661 %, Diferencia de tiempos: +2.092e-05
# Tamaño:    30 - Fuerza Bruta: 1.16e-04s, Divide y Vencerás: 9.43e-05s, Mejora:  +18.6000 %, Diferencia de tiempos: +2.155e-05
# Tamaño:    31 - Fuerza Bruta: 1.24e-04s, Divide y Vencerás: 1.01e-04s, Mejora:  +18.2984 %, Diferencia de tiempos: +2.268e-05
# Tamaño:    32 - Fuerza Bruta: 1.30e-04s, Divide y Vencerás: 9.85e-05s, Mejora:  +24.0854 %, Diferencia de tiempos: +3.124e-05
# Tamaño:    33 - Fuerza Bruta: 1.31e-04s, Divide y Vencerás: 9.78e-05s, Mejora:  +25.2590 %, Diferencia de tiempos: +3.303e-05
# Tamaño:    34 - Fuerza Bruta: 1.40e-04s, Divide y Vencerás: 1.03e-04s, Mejora:  +26.7419 %, Diferencia de tiempos: +3.755e-05
# Tamaño:    35 - Fuerza Bruta: 1.58e-04s, Divide y Vencerás: 1.20e-04s, Mejora:  +23.5242 %, Diferencia de tiempos: +3.706e-05
# Tamaño:    36 - Fuerza Bruta: 1.69e-04s, Divide y Vencerás: 1.19e-04s, Mejora:  +29.6600 %, Diferencia de tiempos: +5.025e-05
# Tamaño:    37 - Fuerza Bruta: 1.67e-04s, Divide y Vencerás: 1.13e-04s, Mejora:  +32.6519 %, Diferencia de tiempos: +5.455e-05
# Tamaño:    38 - Fuerza Bruta: 1.76e-04s, Divide y Vencerás: 1.25e-04s, Mejora:  +29.1494 %, Diferencia de tiempos: +5.144e-05
# Tamaño:    39 - Fuerza Bruta: 1.85e-04s, Divide y Vencerás: 1.26e-04s, Mejora:  +32.2016 %, Diferencia de tiempos: +5.961e-05
# Tamaño:    40 - Fuerza Bruta: 1.98e-04s, Divide y Vencerás: 1.31e-04s, Mejora:  +34.0850 %, Diferencia de tiempos: +6.749e-05
# Tamaño:    41 - Fuerza Bruta: 2.07e-04s, Divide y Vencerás: 1.30e-04s, Mejora:  +37.2977 %, Diferencia de tiempos: +7.732e-05
# Tamaño:    42 - Fuerza Bruta: 2.17e-04s, Divide y Vencerás: 1.45e-04s, Mejora:  +33.3625 %, Diferencia de tiempos: +7.240e-05
# Tamaño:    43 - Fuerza Bruta: 2.19e-04s, Divide y Vencerás: 1.34e-04s, Mejora:  +38.9222 %, Diferencia de tiempos: +8.534e-05
# Tamaño:    44 - Fuerza Bruta: 2.40e-04s, Divide y Vencerás: 1.54e-04s, Mejora:  +35.8126 %, Diferencia de tiempos: +8.594e-05
# Tamaño:    45 - Fuerza Bruta: 2.47e-04s, Divide y Vencerás: 1.54e-04s, Mejora:  +37.6257 %, Diferencia de tiempos: +9.295e-05
# Tamaño:    46 - Fuerza Bruta: 2.42e-04s, Divide y Vencerás: 1.53e-04s, Mejora:  +36.8470 %, Diferencia de tiempos: +8.905e-05
# Tamaño:    47 - Fuerza Bruta: 2.71e-04s, Divide y Vencerás: 1.50e-04s, Mejora:  +44.8092 %, Diferencia de tiempos: +1.216e-04
# Tamaño:    48 - Fuerza Bruta: 2.73e-04s, Divide y Vencerás: 1.61e-04s, Mejora:  +40.9055 %, Diferencia de tiempos: +1.117e-04
# Tamaño:    49 - Fuerza Bruta: 2.89e-04s, Divide y Vencerás: 1.55e-04s, Mejora:  +46.2195 %, Diferencia de tiempos: +1.334e-04
# Tamaño:    50 - Fuerza Bruta: 3.02e-04s, Divide y Vencerás: 1.61e-04s, Mejora:  +46.5062 %, Diferencia de tiempos: +1.403e-04
# Tamaño:    60 - Fuerza Bruta: 4.26e-04s, Divide y Vencerás: 2.03e-04s, Mejora:  +52.2942 %, Diferencia de tiempos: +2.230e-04
# Tamaño:    70 - Fuerza Bruta: 5.61e-04s, Divide y Vencerás: 2.40e-04s, Mejora:  +57.2132 %, Diferencia de tiempos: +3.209e-04
# Tamaño:    80 - Fuerza Bruta: 7.73e-04s, Divide y Vencerás: 2.89e-04s, Mejora:  +62.6437 %, Diferencia de tiempos: +4.845e-04
# Tamaño:    90 - Fuerza Bruta: 1.01e-03s, Divide y Vencerás: 3.32e-04s, Mejora:  +66.9814 %, Diferencia de tiempos: +6.737e-04
# Tamaño:   100 - Fuerza Bruta: 1.11e-03s, Divide y Vencerás: 3.55e-04s, Mejora:  +68.0310 %, Diferencia de tiempos: +7.563e-04
# Tamaño:   110 - Fuerza Bruta: 1.28e-03s, Divide y Vencerás: 3.78e-04s, Mejora:  +70.4734 %, Diferencia de tiempos: +9.021e-04
# Tamaño:   120 - Fuerza Bruta: 1.61e-03s, Divide y Vencerás: 4.09e-04s, Mejora:  +74.5224 %, Diferencia de tiempos: +1.197e-03
# Tamaño:   130 - Fuerza Bruta: 1.84e-03s, Divide y Vencerás: 4.20e-04s, Mejora:  +77.1330 %, Diferencia de tiempos: +1.418e-03
# Tamaño:   140 - Fuerza Bruta: 2.17e-03s, Divide y Vencerás: 5.01e-04s, Mejora:  +76.8865 %, Diferencia de tiempos: +1.667e-03
# Tamaño:   150 - Fuerza Bruta: 2.47e-03s, Divide y Vencerás: 5.32e-04s, Mejora:  +78.4524 %, Diferencia de tiempos: +1.936e-03
# Tamaño:   160 - Fuerza Bruta: 2.74e-03s, Divide y Vencerás: 5.72e-04s, Mejora:  +79.1247 %, Diferencia de tiempos: +2.168e-03
# Tamaño:   170 - Fuerza Bruta: 3.17e-03s, Divide y Vencerás: 6.07e-04s, Mejora:  +80.8382 %, Diferencia de tiempos: +2.561e-03
# Tamaño:   180 - Fuerza Bruta: 3.46e-03s, Divide y Vencerás: 6.49e-04s, Mejora:  +81.2374 %, Diferencia de tiempos: +2.812e-03
# Tamaño:   190 - Fuerza Bruta: 3.97e-03s, Divide y Vencerás: 7.02e-04s, Mejora:  +82.3276 %, Diferencia de tiempos: +3.271e-03
# Tamaño:   200 - Fuerza Bruta: 4.55e-03s, Divide y Vencerás: 7.41e-04s, Mejora:  +83.7339 %, Diferencia de tiempos: +3.814e-03
# Tamaño:   210 - Fuerza Bruta: 4.96e-03s, Divide y Vencerás: 7.79e-04s, Mejora:  +84.2758 %, Diferencia de tiempos: +4.176e-03
# Tamaño:   220 - Fuerza Bruta: 5.31e-03s, Divide y Vencerás: 7.82e-04s, Mejora:  +85.2773 %, Diferencia de tiempos: +4.530e-03
# Tamaño:   230 - Fuerza Bruta: 5.74e-03s, Divide y Vencerás: 7.93e-04s, Mejora:  +86.1886 %, Diferencia de tiempos: +4.951e-03
# Tamaño:   240 - Fuerza Bruta: 6.44e-03s, Divide y Vencerás: 9.11e-04s, Mejora:  +85.8593 %, Diferencia de tiempos: +5.529e-03
# Tamaño:   250 - Fuerza Bruta: 6.87e-03s, Divide y Vencerás: 8.80e-04s, Mejora:  +87.1843 %, Diferencia de tiempos: +5.989e-03
# Tamaño:   260 - Fuerza Bruta: 7.35e-03s, Divide y Vencerás: 9.28e-04s, Mejora:  +87.3762 %, Diferencia de tiempos: +6.420e-03
# Tamaño:   270 - Fuerza Bruta: 7.75e-03s, Divide y Vencerás: 9.74e-04s, Mejora:  +87.4378 %, Diferencia de tiempos: +6.777e-03
# Tamaño:   280 - Fuerza Bruta: 9.34e-03s, Divide y Vencerás: 1.15e-03s, Mejora:  +87.6482 %, Diferencia de tiempos: +8.185e-03
# Tamaño:   290 - Fuerza Bruta: 9.12e-03s, Divide y Vencerás: 1.07e-03s, Mejora:  +88.2522 %, Diferencia de tiempos: +8.052e-03
# Tamaño:   300 - Fuerza Bruta: 9.90e-03s, Divide y Vencerás: 1.16e-03s, Mejora:  +88.2773 %, Diferencia de tiempos: +8.740e-03
# Tamaño:   310 - Fuerza Bruta: 1.06e-02s, Divide y Vencerás: 1.18e-03s, Mejora:  +88.7852 %, Diferencia de tiempos: +9.373e-03
# Tamaño:   320 - Fuerza Bruta: 1.12e-02s, Divide y Vencerás: 1.22e-03s, Mejora:  +89.0822 %, Diferencia de tiempos: +9.961e-03
# Tamaño:   330 - Fuerza Bruta: 1.23e-02s, Divide y Vencerás: 1.30e-03s, Mejora:  +89.4544 %, Diferencia de tiempos: +1.099e-02
# Tamaño:   340 - Fuerza Bruta: 1.29e-02s, Divide y Vencerás: 1.36e-03s, Mejora:  +89.5034 %, Diferencia de tiempos: +1.158e-02
# Tamaño:   350 - Fuerza Bruta: 1.35e-02s, Divide y Vencerás: 1.37e-03s, Mejora:  +89.9239 %, Diferencia de tiempos: +1.218e-02
# Tamaño:   360 - Fuerza Bruta: 1.44e-02s, Divide y Vencerás: 1.44e-03s, Mejora:  +89.9992 %, Diferencia de tiempos: +1.300e-02
# Tamaño:   370 - Fuerza Bruta: 1.52e-02s, Divide y Vencerás: 1.46e-03s, Mejora:  +90.3844 %, Diferencia de tiempos: +1.374e-02
# Tamaño:   380 - Fuerza Bruta: 1.61e-02s, Divide y Vencerás: 1.55e-03s, Mejora:  +90.3587 %, Diferencia de tiempos: +1.456e-02
# Tamaño:   390 - Fuerza Bruta: 1.68e-02s, Divide y Vencerás: 1.52e-03s, Mejora:  +90.9090 %, Diferencia de tiempos: +1.523e-02
# Tamaño:   400 - Fuerza Bruta: 1.81e-02s, Divide y Vencerás: 1.61e-03s, Mejora:  +91.0794 %, Diferencia de tiempos: +1.645e-02
# Tamaño:   410 - Fuerza Bruta: 1.87e-02s, Divide y Vencerás: 1.65e-03s, Mejora:  +91.1929 %, Diferencia de tiempos: +1.705e-02
# Tamaño:   420 - Fuerza Bruta: 1.95e-02s, Divide y Vencerás: 1.62e-03s, Mejora:  +91.7229 %, Diferencia de tiempos: +1.793e-02
# Tamaño:   430 - Fuerza Bruta: 2.07e-02s, Divide y Vencerás: 1.71e-03s, Mejora:  +91.7356 %, Diferencia de tiempos: +1.896e-02
# Tamaño:   440 - Fuerza Bruta: 2.18e-02s, Divide y Vencerás: 1.75e-03s, Mejora:  +91.9767 %, Diferencia de tiempos: +2.001e-02
# Tamaño:   450 - Fuerza Bruta: 2.37e-02s, Divide y Vencerás: 1.81e-03s, Mejora:  +92.3569 %, Diferencia de tiempos: +2.188e-02
# Tamaño:   460 - Fuerza Bruta: 2.36e-02s, Divide y Vencerás: 1.81e-03s, Mejora:  +92.3475 %, Diferencia de tiempos: +2.184e-02
# Tamaño:   470 - Fuerza Bruta: 2.51e-02s, Divide y Vencerás: 1.81e-03s, Mejora:  +92.7610 %, Diferencia de tiempos: +2.325e-02
# Tamaño:   480 - Fuerza Bruta: 2.72e-02s, Divide y Vencerás: 2.00e-03s, Mejora:  +92.6630 %, Diferencia de tiempos: +2.524e-02
# Tamaño:   490 - Fuerza Bruta: 2.69e-02s, Divide y Vencerás: 1.89e-03s, Mejora:  +92.9749 %, Diferencia de tiempos: +2.497e-02
# Tamaño:   500 - Fuerza Bruta: 2.81e-02s, Divide y Vencerás: 1.93e-03s, Mejora:  +93.1310 %, Diferencia de tiempos: +2.616e-02
# Tamaño:   510 - Fuerza Bruta: 2.94e-02s, Divide y Vencerás: 1.99e-03s, Mejora:  +93.2133 %, Diferencia de tiempos: +2.740e-02
# Tamaño:   520 - Fuerza Bruta: 3.03e-02s, Divide y Vencerás: 2.05e-03s, Mejora:  +93.2278 %, Diferencia de tiempos: +2.829e-02
# Tamaño:   530 - Fuerza Bruta: 3.21e-02s, Divide y Vencerás: 2.26e-03s, Mejora:  +92.9670 %, Diferencia de tiempos: +2.981e-02
# Tamaño:   540 - Fuerza Bruta: 3.34e-02s, Divide y Vencerás: 2.13e-03s, Mejora:  +93.6170 %, Diferencia de tiempos: +3.129e-02
# Tamaño:   550 - Fuerza Bruta: 3.43e-02s, Divide y Vencerás: 2.22e-03s, Mejora:  +93.5265 %, Diferencia de tiempos: +3.210e-02
# Tamaño:   560 - Fuerza Bruta: 3.55e-02s, Divide y Vencerás: 2.23e-03s, Mejora:  +93.7154 %, Diferencia de tiempos: +3.326e-02
# Tamaño:   570 - Fuerza Bruta: 3.66e-02s, Divide y Vencerás: 2.26e-03s, Mejora:  +93.8171 %, Diferencia de tiempos: +3.432e-02
# Tamaño:   580 - Fuerza Bruta: 3.92e-02s, Divide y Vencerás: 2.69e-03s, Mejora:  +93.1296 %, Diferencia de tiempos: +3.648e-02
# Tamaño:   590 - Fuerza Bruta: 4.01e-02s, Divide y Vencerás: 2.39e-03s, Mejora:  +94.0408 %, Diferencia de tiempos: +3.771e-02
# Tamaño:   600 - Fuerza Bruta: 4.09e-02s, Divide y Vencerás: 2.44e-03s, Mejora:  +94.0227 %, Diferencia de tiempos: +3.845e-02
# Tamaño:   610 - Fuerza Bruta: 4.24e-02s, Divide y Vencerás: 2.52e-03s, Mejora:  +94.0478 %, Diferencia de tiempos: +3.984e-02
# Tamaño:   620 - Fuerza Bruta: 4.37e-02s, Divide y Vencerás: 2.59e-03s, Mejora:  +94.0794 %, Diferencia de tiempos: +4.110e-02
# Tamaño:   630 - Fuerza Bruta: 4.51e-02s, Divide y Vencerás: 2.55e-03s, Mejora:  +94.3522 %, Diferencia de tiempos: +4.255e-02
# Tamaño:   640 - Fuerza Bruta: 4.70e-02s, Divide y Vencerás: 2.65e-03s, Mejora:  +94.3566 %, Diferencia de tiempos: +4.434e-02
# Tamaño:   650 - Fuerza Bruta: 4.84e-02s, Divide y Vencerás: 2.70e-03s, Mejora:  +94.4176 %, Diferencia de tiempos: +4.568e-02
# Tamaño:   660 - Fuerza Bruta: 4.99e-02s, Divide y Vencerás: 2.72e-03s, Mejora:  +94.5599 %, Diferencia de tiempos: +4.719e-02
# Tamaño:   670 - Fuerza Bruta: 5.19e-02s, Divide y Vencerás: 2.77e-03s, Mejora:  +94.6711 %, Diferencia de tiempos: +4.918e-02
# Tamaño:   680 - Fuerza Bruta: 5.22e-02s, Divide y Vencerás: 2.85e-03s, Mejora:  +94.5451 %, Diferencia de tiempos: +4.935e-02
# Tamaño:   690 - Fuerza Bruta: 5.53e-02s, Divide y Vencerás: 3.04e-03s, Mejora:  +94.5059 %, Diferencia de tiempos: +5.224e-02
# Tamaño:   700 - Fuerza Bruta: 5.59e-02s, Divide y Vencerás: 2.88e-03s, Mejora:  +94.8474 %, Diferencia de tiempos: +5.302e-02
# Tamaño:   710 - Fuerza Bruta: 5.90e-02s, Divide y Vencerás: 3.04e-03s, Mejora:  +94.8468 %, Diferencia de tiempos: +5.600e-02
# Tamaño:   720 - Fuerza Bruta: 5.93e-02s, Divide y Vencerás: 3.09e-03s, Mejora:  +94.7909 %, Diferencia de tiempos: +5.619e-02
# Tamaño:   730 - Fuerza Bruta: 6.20e-02s, Divide y Vencerás: 3.16e-03s, Mejora:  +94.8999 %, Diferencia de tiempos: +5.883e-02
# Tamaño:   740 - Fuerza Bruta: 6.63e-02s, Divide y Vencerás: 3.31e-03s, Mejora:  +95.0083 %, Diferencia de tiempos: +6.298e-02
# Tamaño:   750 - Fuerza Bruta: 6.46e-02s, Divide y Vencerás: 3.26e-03s, Mejora:  +94.9493 %, Diferencia de tiempos: +6.136e-02
# Tamaño:   760 - Fuerza Bruta: 6.91e-02s, Divide y Vencerás: 3.29e-03s, Mejora:  +95.2325 %, Diferencia de tiempos: +6.578e-02
# Tamaño:   770 - Fuerza Bruta: 6.80e-02s, Divide y Vencerás: 3.32e-03s, Mejora:  +95.1168 %, Diferencia de tiempos: +6.467e-02
# Tamaño:   780 - Fuerza Bruta: 7.13e-02s, Divide y Vencerás: 3.34e-03s, Mejora:  +95.3100 %, Diferencia de tiempos: +6.793e-02
# Tamaño:   790 - Fuerza Bruta: 7.04e-02s, Divide y Vencerás: 3.43e-03s, Mejora:  +95.1241 %, Diferencia de tiempos: +6.696e-02
# Tamaño:   800 - Fuerza Bruta: 7.30e-02s, Divide y Vencerás: 3.42e-03s, Mejora:  +95.3100 %, Diferencia de tiempos: +6.959e-02
# Tamaño:   810 - Fuerza Bruta: 7.48e-02s, Divide y Vencerás: 3.50e-03s, Mejora:  +95.3217 %, Diferencia de tiempos: +7.134e-02
# Tamaño:   820 - Fuerza Bruta: 7.72e-02s, Divide y Vencerás: 3.53e-03s, Mejora:  +95.4186 %, Diferencia de tiempos: +7.362e-02
# Tamaño:   830 - Fuerza Bruta: 7.92e-02s, Divide y Vencerás: 4.18e-03s, Mejora:  +94.7312 %, Diferencia de tiempos: +7.507e-02
# Tamaño:   840 - Fuerza Bruta: 8.07e-02s, Divide y Vencerás: 3.63e-03s, Mejora:  +95.4984 %, Diferencia de tiempos: +7.711e-02
# Tamaño:   850 - Fuerza Bruta: 8.33e-02s, Divide y Vencerás: 3.57e-03s, Mejora:  +95.7113 %, Diferencia de tiempos: +7.973e-02
# Tamaño:   860 - Fuerza Bruta: 8.48e-02s, Divide y Vencerás: 3.66e-03s, Mejora:  +95.6839 %, Diferencia de tiempos: +8.111e-02
# Tamaño:   870 - Fuerza Bruta: 8.64e-02s, Divide y Vencerás: 3.64e-03s, Mejora:  +95.7866 %, Diferencia de tiempos: +8.279e-02
# Tamaño:   880 - Fuerza Bruta: 8.85e-02s, Divide y Vencerás: 3.66e-03s, Mejora:  +95.8620 %, Diferencia de tiempos: +8.485e-02
# Tamaño:   890 - Fuerza Bruta: 9.11e-02s, Divide y Vencerás: 3.70e-03s, Mejora:  +95.9372 %, Diferencia de tiempos: +8.740e-02
# Tamaño:   900 - Fuerza Bruta: 9.22e-02s, Divide y Vencerás: 3.77e-03s, Mejora:  +95.9084 %, Diferencia de tiempos: +8.838e-02
# Tamaño:   910 - Fuerza Bruta: 9.44e-02s, Divide y Vencerás: 3.75e-03s, Mejora:  +96.0238 %, Diferencia de tiempos: +9.064e-02
# Tamaño:   920 - Fuerza Bruta: 9.64e-02s, Divide y Vencerás: 3.97e-03s, Mejora:  +95.8817 %, Diferencia de tiempos: +9.246e-02
# Tamaño:   930 - Fuerza Bruta: 1.00e-01s, Divide y Vencerás: 4.07e-03s, Mejora:  +95.9462 %, Diferencia de tiempos: +9.628e-02
# Tamaño:   940 - Fuerza Bruta: 1.02e-01s, Divide y Vencerás: 3.98e-03s, Mejora:  +96.1206 %, Diferencia de tiempos: +9.850e-02
# Tamaño:   950 - Fuerza Bruta: 1.03e-01s, Divide y Vencerás: 4.08e-03s, Mejora:  +96.0241 %, Diferencia de tiempos: +9.856e-02
# Tamaño:   960 - Fuerza Bruta: 1.06e-01s, Divide y Vencerás: 4.12e-03s, Mejora:  +96.1098 %, Diferencia de tiempos: +1.017e-01
# Tamaño:   970 - Fuerza Bruta: 1.09e-01s, Divide y Vencerás: 4.00e-03s, Mejora:  +96.3459 %, Diferencia de tiempos: +1.054e-01
# Tamaño:   980 - Fuerza Bruta: 1.12e-01s, Divide y Vencerás: 4.16e-03s, Mejora:  +96.2920 %, Diferencia de tiempos: +1.079e-01
# Tamaño:   990 - Fuerza Bruta: 1.14e-01s, Divide y Vencerás: 4.46e-03s, Mejora:  +96.0707 %, Diferencia de tiempos: +1.091e-01
# Tamaño:  1000 - Fuerza Bruta: 1.14e-01s, Divide y Vencerás: 4.21e-03s, Mejora:  +96.3218 %, Diferencia de tiempos: +1.103e-01
# Tamaño:  2000 - Fuerza Bruta: 4.62e-01s, Divide y Vencerás: 8.74e-03s, Mejora:  +98.1091 %, Diferencia de tiempos: +4.533e-01
# Tamaño:  3000 - Fuerza Bruta: 1.02e+00s, Divide y Vencerás: 1.42e-02s, Mejora:  +98.6090 %, Diferencia de tiempos: +1.009e+00
# Tamaño:  4000 - Fuerza Bruta: 1.82e+00s, Divide y Vencerás: 1.97e-02s, Mejora:  +98.9165 %, Diferencia de tiempos: +1.801e+00
# Tamaño:  5000 - Fuerza Bruta: 2.84e+00s, Divide y Vencerás: 2.41e-02s, Mejora:  +99.1531 %, Diferencia de tiempos: +2.820e+00
# Tamaño:  6000 - Fuerza Bruta: 4.10e+00s, Divide y Vencerás: 3.04e-02s, Mejora:  +99.2596 %, Diferencia de tiempos: +4.071e+00
# Tamaño:  7000 - Fuerza Bruta: 5.59e+00s, Divide y Vencerás: 3.44e-02s, Mejora:  +99.3844 %, Diferencia de tiempos: +5.557e+00
# Tamaño:  8000 - Fuerza Bruta: 7.30e+00s, Divide y Vencerás: 3.86e-02s, Mejora:  +99.4708 %, Diferencia de tiempos: +7.257e+00
# Tamaño:  9000 - Fuerza Bruta: 9.23e+00s, Divide y Vencerás: 4.52e-02s, Mejora:  +99.5102 %, Diferencia de tiempos: +9.189e+00
